# %%
import pandas as pd

import pymongo

import json

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.park_species
collection = db.glacier

# %%
combined_dataframe = pd.read_csv("status_all_taxon_MOSHER.csv")

# %%
c_df = combined_dataframe.set_index('Scientific Name')
c_df = c_df.reset_index()

# %%
c_df = c_df.to_json(orient='records')

# %%
print(c_df)
# Out:
# [{"Scientific Name":"Addax nasomaculatus","Unnamed: 0":0,"Common Name":"Addax","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Bubalus depressicornis","Unnamed: 0":1,"Common Name":"Anoa, lowland","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Bubalus quarlesi","Unnamed: 0":2,"Common Name":"Anoa, mountain","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Hippotragus niger variani","Unnamed: 0":3,"Common Name":"Antelope, giant sable","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Panthalops hodgsonii","Unnamed: 0":4,"Common Name":"Antelope, Tibetan","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Ovis ammon","Unnamed: 0":5,"Common Name":"Argali [All populations except Kyrgyzstan, Mongolia, and Tajikistan]","Status":"Endangered","Taxon Group":"Mammal"},{"Scientific Name":"Ovis ammon","Unnamed: 0":6,"Common Name":"Argali [Kyrgyzstan, Mongolia, and Tajikistan]","Status":"Threatened","Taxon Group":"M
# ...

# %%
# c_df.replace('', null)
#c_df = c_df.to_dict()
final_combined_dataframe = json.loads(c_df)

# %%
print(type(final_combined_dataframe))
# Out:
# <class 'list'>

# %%
db.glacier.drop
# Out:
# <bound method Collection.drop of Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'park_species'), 'glacier')>

# %%
db.glacier.insert_many(final_combined_dataframe)
